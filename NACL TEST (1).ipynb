# %% [markdown]
#  # A SMART, MOBILE PLATFORM FOR AIR-QUALITY MONITORING
#
#
#
# ********************************************************************************************************************************
# ### Nueraili Kuerbanjiang, Meilu He  and Suresh Dhaniyala
#
#
# ### Clarkson University
#
#
#
# ****************************************************************************************************************************************************************************************************************************************************************
# ## * This is an inside report created by Nueraili Kuerbanjiang
# ****************************************************************************************************************************************************************************************************************************************************************

# %% [markdown]
# *******************************
# *******************************
# *******************************
# *******************************
# # NACL Test
#
# Testing Particle Sizes are 300 NM, 400 NM, 500 NM

# %% [markdown]
# ## Test Record
#
# ### June 13th 2018
#
# Particle source NACL;  Aerosol Flow :3 LPM;  Sheet Flow:12 LPM;
#
# Tunnel Frequency as 12 HZ;
#
# CPC 3786 As reference;
#
# Nueraili Kuerbanjiang ,  Meilu He;
#
# ******************
# NACL solution 1%
#
# Tunnel Testing for NACL 300 NM to 500 NM;
#
# Nueraili Kuerbanjiang;
#
# ***************
# 2:45 Inject Particle Size as 300 nm;
#
# 2:55 Clean The Box;
#
# 3:00 Reinject the particle in low concentrations;
#
# 3:15 Increase Particle concentrations;
#
# 3:30 Max Particle Concentration;
#
# 3:50 Clean The Box;
#
# **********************
#
# 4:00  Inject 400 nm Particles;
#
# 4:15Increae Particle Concentrations;
#
# 4:30 Max the concentration;
#
# 4:47 Clean the box;
#
# *********************
# 4:55 Inject 500 nm Particles;
#
# 5:10 Max the Concentration;
#
# 5:25 Max the Concentration;
#
# 5:35 Clean the Box;
#
# 5:40 Stop the test;

# %% [markdown]
# ## CPC DATA

# %%
import numpy as np
import pandas as pd
import json
from datetime import datetime
import pytz

df1=pd.read_csv('c:\\users\\tyler\\Desktop\\data\\nacl_cpc_0613.csv')
df1.columns = ["time","concentration"]

df1['time'] = pd.to_datetime(df1['time'],unit='s')

df1.head()
# Out:
#                  time  concentration
# 0 2018-06-13 14:18:04         1980.0
# 1 2018-06-13 14:18:05         1960.0
# 2 2018-06-13 14:18:06         1950.0
# 3 2018-06-13 14:18:07         1960.0
# 4 2018-06-13 14:18:08         1990.0

# %%
df1.describe()
# Out:
#        concentration
# count   12420.000000
# mean     2826.288513
# std      3094.119010
# min        -0.090000
# 25%        86.600000
# 50%      1870.000000
# 75%      3220.000000
# max     13500.000000

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()
plt.plot(df1['time'],df1['concentration'],label=r'$CPC$')
plt.legend(loc='best',fontsize=20)
plt.title('$ NACL $  $TEST$ $CPC$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$Particle$ $Concentration$',fontsize=17)
plt.show()

# %% [markdown]
# # Low Cost Sensors Data

# %%
df2=pd.read_csv('c:\\users\\tyler\\Desktop\\data\\nac2.csv')
df2.columns = ["time","temp","rh","inwindspeed","exwindspeed","PM1.0","PM2.5",
               "PM10","PM1.0adj","PM2.5adj","PM10adj","0.3um","0.5um","1um","2.5um","5um","10um","honeywell_PM2.5",
               "honeywell_PM10","shinyei","samyoung"]
df2['time'] = pd.to_datetime(df2['time'],unit='s')

df2.head()
# Out:
#                  time   temp     rh  inwindspeed  exwindspeed  PM1.0  PM2.5  \
# 0 2018-06-13 14:17:17  22.62  76.10        13.05         0.54      7     10
# 1 2018-06-13 14:17:23  22.64  76.16        13.81        28.55      8     10
# 2 2018-06-13 14:17:30  22.66  76.04        12.91        -4.56      8     10
# 3 2018-06-13 14:17:36  22.66  76.05        13.43       -15.38      8     10
# 4 2018-06-13 14:17:43  22.67  76.04        12.90         6.90      8     10
#
#    PM10  PM1.0adj  PM2.5adj    ...      0.3um  0.5um   1um  2.5um  5um  10um  \
# 0  10.0       7.0      10.0    ...     1539.0  440.0  64.0    4.0  0.0   0.0
# 1  11.0       8.0      10.0    ...     1488.0  434.0  57.0    5.0  1.0   0.0
# 2  11.0       8.0      10.0    ...     1473.0  428.0  60.0    4.0  1.0   0.0
# 3  11.0       8.0      10.0    ...     1539.0  460.0  71.0    4.0  1.0   0.0
# 4  11.0       8.0      10.0    ...     1512.0  459.0  79.0    2.0  1.0   0.0
#
# ...

# %%
df2.describe()
# Out:
#               temp           rh  inwindspeed  exwindspeed        PM1.0  \
# count  1947.000000  1947.000000  1947.000000  1947.000000  1947.000000
# mean     22.060503    69.746502    10.800950    12.451957     7.969697
# std       0.299185     4.562862     1.866937    15.025601    10.540657
# min      21.580000    63.130000     6.040000   -27.480000     0.000000
# 25%      21.840000    66.410000     9.360000     3.080000     0.000000
# 50%      21.980000    67.830000    10.590000    17.090000     3.000000
# 75%      22.290000    73.725000    12.190000    23.140000    10.000000
# max      22.820000    79.960000    15.680000    37.460000    45.000000
#
#              PM2.5         PM10     PM1.0adj     PM2.5adj      PM10adj  \
# count  1947.000000  1947.000000  1947.000000  1896.000000  1896.000000
# mean     13.144838    13.900570     6.723683    11.854958    13.949895
# std      15.011115    15.825445     8.499791    12.786601    15.153328
# ...

# %% [markdown]
# # Let's look at the Temperature

# %%
df2.temp.describe()
# Out:
# count    1947.000000
# mean       22.060503
# std         0.299185
# min        21.580000
# 25%        21.840000
# 50%        21.980000
# 75%        22.290000
# max        22.820000
# Name: temp, dtype: float64

# %%
df2.temp.hist()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(df2['time'],df2['temp'], 'g-')
ax2.plot(df1['time'],df1['concentration'], 'b-')

#plt.plot(df2['Time_lcs'],df2['PM1.0'],label=r'Plantower PM1.0')
plt.legend(loc='best',fontsize=17)
plt.title(' $Fan$ $VS$ $Temp$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$PM$',fontsize=17)

plt.show()

# %% [markdown]
# # Relative Humidity %

# %%
df2.rh.describe()
# Out:
# count    1947.000000
# mean       69.746502
# std         4.562862
# min        63.130000
# 25%        66.410000
# 50%        67.830000
# 75%        73.725000
# max        79.960000
# Name: rh, dtype: float64

# %%
df2.boxplot(column='rh')

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(df1['time'],df1['concentration'], 'b-')
ax2.plot(df2['time'],df2['rh'], 'g-')


#plt.plot(df2['Time_lcs'],df2['PM1.0'],label=r'Plantower PM1.0')
plt.legend(loc='best',fontsize=17)
plt.title(' $Fan$ $VS$ $RH$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$Humidity$',fontsize=17)

plt.show()

# %% [markdown]
# # Windspeed Sensors Inseide the Box

# %%
df2.inwindspeed.describe()
# Out:
# count    1947.000000
# mean       10.800950
# std         1.866937
# min         6.040000
# 25%         9.360000
# 50%        10.590000
# 75%        12.190000
# max        15.680000
# Name: inwindspeed, dtype: float64

# %%
df2.inwindspeed.hist()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(df1['time'],df1['concentration'], 'b-')
ax2.plot(df2['time'],df2['inwindspeed'], 'g-')


#plt.plot(df2['Time_lcs'],df2['PM1.0'],label=r'Plantower PM1.0')
plt.legend(loc='best',fontsize=17)
plt.title(' $Fan$ $VS$ $Windspeed$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$windspeed$',fontsize=17)

plt.show()

# %% [markdown]
# # Merge CPC data to Low Cost Sensors Data Based On Time

# %%
df3=pd.merge(df1,df2,on="time")

df3.tail()
# Out:
#                     time  concentration   temp     rh  inwindspeed  \
# 1905 2018-06-13 17:44:31           29.6  22.64  79.55        12.61
# 1906 2018-06-13 17:44:38           28.8  22.64  79.54        12.26
# 1907 2018-06-13 17:44:44           25.8  22.65  79.54        13.97
# 1908 2018-06-13 17:44:51           33.2  22.65  79.58        14.34
# 1909 2018-06-13 17:44:57           32.2  22.65  79.53        12.33
#
#       exwindspeed  PM1.0  PM2.5  PM10  PM1.0adj    ...     0.3um  0.5um  1um  \
# 1905        19.64      0      0   0.0       0.0    ...      21.0    7.0  1.0
# 1906        12.63      0      0   0.0       0.0    ...      24.0    8.0  3.0
# 1907        16.45      0      0   0.0       0.0    ...      30.0    9.0  3.0
# 1908        23.46      0      0   0.0       0.0    ...      33.0   10.0  3.0
# 1909         4.99      0      0   0.0       0.0    ...      33.0   10.0  3.0
#
#       2.5um  5um  10um  honeywell_PM2.5  honeywell_PM10  shinyei  samyoung
# ...

# %% [markdown]
# # Plot and check if it's correct

# %%
plt.plot(df3['time'],df3['concentration'])

# %% [markdown]
# # Plot CPC and Windspeed

# %%
# %matplotlib inline
plt.plot(df3['concentration'],df3['inwindspeed'],'o')
plt.show()

# %% [markdown]
# ***********
# ***********
# ***********
# ***********
# I Tried to Do R2 and see the corrolation of these two data,
# And i relised that the Size was different , so Can't just get he cpc concentration data and compare it with windspeed;
#
#
# *************
# It should be compare in one size range.
#
# However,it's too late, I need to sleep
# **************
# *************
# ***************

# %% [markdown]
# # Windspeed Sensors Outseide the Box

# %%
df2.exwindspeed.describe()
# Out:
# count    1947.000000
# mean       12.451957
# std        15.025601
# min       -27.480000
# 25%         3.080000
# 50%        17.090000
# 75%        23.140000
# max        37.460000
# Name: exwindspeed, dtype: float64

# %%
df2.exwindspeed.hist()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('dark_background')
plt.figure()
plt.plot(df2['time'],df2['exwindspeed'],label=r'$Windspeed$')
plt.legend(loc='best',fontsize=20)
plt.title('$ Windspeed $',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$Windspeed$',fontsize=17)
plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(df3['time'],df3['concentration'], 'b-')
ax2.plot(df3['time'],df3['0.3um'], 'g-')


#plt.plot(df2['Time_lcs'],df2['PM1.0'],label=r'Plantower PM1.0')
plt.legend(loc='best',fontsize=17)
plt.title(' $plantower$ $VS$ $CPC$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$CPC$',fontsize=17)

plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(df3['time'],df3['concentration'], 'b-')
ax2.plot(df3['time'],df3['0.5um'], 'g-')


#plt.plot(df2['Time_lcs'],df2['PM1.0'],label=r'Plantower PM1.0')
plt.legend(loc='best',fontsize=17)
plt.title(' $plantower$ $VS$ $CPC$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$CPC$',fontsize=17)

plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='svg'

import matplotlib.pyplot as plt

plt.rcParams['figure.figsize']=(12,7)
plt.style.use('seaborn')
plt.figure()

fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.plot(df3['time'],df3['concentration'], 'b-')
ax2.plot(df3['time'],df3['honeywell_PM2.5'], 'g-')


#plt.plot(df2['Time_lcs'],df2['PM1.0'],label=r'Plantower PM1.0')
plt.legend(loc='best',fontsize=17)
plt.title(' $Honeywell$ $VS$ $CPC$ $DATA$',fontsize=20)
plt.xlabel('$Time$',fontsize=17)
plt.ylabel('$Honeywell$',fontsize=17)

plt.show()

# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di # Example: di.display_html('<h3>%s:</h3>' % str, raw=True)

# This line will hide code by default when the notebook is exported as HTML
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)

# This line will add a button to toggle visibility of code blocks, for use with the HTML export version
di.display_html('''<button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>''', raw=True)
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <button onclick="jQuery('.input_area').toggle(); jQuery('.prompt').toggle();">Toggle code</button>
